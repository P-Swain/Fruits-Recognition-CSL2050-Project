# %% [markdown]
# ## **Import Libraries** ##

# %%
# Importing req. libraries
import os
import numpy as np
from PIL import Image
from skimage.feature import hog
from skimage.feature import local_binary_pattern as lbp
from skimage import exposure
import cv2

# %% [markdown]
# ## **Convert Img to Numpy Array** ##

# %%
# Function to load image data and convert to numpy array
def convertImgToNumpyArr(image_path):
    try:
        img = Image.open(image_path)  # creating reference variable img to access image data
        img = img.resize((100, 100))  # resize image to 100x100 in case it is not
        img = np.array(img)  # converting image data from JPG to numpy array
        #img = img / 255.0  # normalizing RGB values (cv2 needs 0-255 range)
        return img
    except Exception as e:
        print(f"Error processing image {image_path}: {e}")  # error handling
        return None

# %% [markdown]
# ## **Compute HOG Features** ##

# %%
# Function to compute HOG features of an image
def computeHOGFeatures(image):
    
    # conversion to grayscale
    grayImg = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    grayImg = grayImg / 255.0  # normalizing

    # computing HOG features
    hogFeatures, hogImg = hog(grayImg, pixels_per_cell=(16,16), orientations=9, cells_per_block=(2, 2), visualize=True) # 9 orientations, 8x8 pixels per cell, 2x2 cells per block

    # increasing the contrast of the image
    hogImg = exposure.rescale_intensity(hogImg, in_range=(0, 10))

    return hogFeatures, hogImg

# %% [markdown]
# ## **Compute LBP Features** ##

# %%
def computeLBP_Features(image):

     # conversion to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

    # computing LBP features
    lbpImg = lbp(gray, method="uniform", P = 8, R = 1) 
    
    bins = np.arange(0, 11) # number of bins for histogram (10)
    lbpHist, _ = np.histogram(lbpImg.flatten(), bins=bins, range=(0, 10)) # computing histogram

    return lbpHist / (np.sum(lbpHist) + 1e-6)

# %% [markdown]
# ## **Compute Colour Histogram Features** ##

# %%
# Function to compute colour histogram features for an image

def computeColourHist(image, bins=20):

    # conversion from RGB to HSV
    hsvImg = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
    
    hsvImg = hsvImg / 255.0  # normalizing
    
    # extracting histograms for Hue, Saturation, and Value
    hueHist = np.histogram(hsvImg[:,:,0], bins=bins, range=(0, 1))[0]  
    satHist = np.histogram(hsvImg[:,:,1], bins=bins, range=(0, 1))[0]  
    valHist = np.histogram(hsvImg[:,:,2], bins=bins, range=(0, 1))[0]  
    
    # concatenating the histograms of Hue, Saturation, and Value and returning
    return np.concatenate((hueHist, satHist, valHist))

# %% [markdown]
# ## **Extracting Features** ##

# %%
# Function to extract features and save them as numpy arrays
def saveImgFeaturesAsNumpyArr(src_path, save_path, featuresDescriptors = ['colour', 'shape', 'texture']):
    print(f"Original Image Folder: {src_path}")
    os.makedirs(os.path.dirname(save_path), exist_ok=True)  # creating the save folder if it doesn't exist
    print(f"Saving Image Features Folder: {save_path}")
    
    # # print feature descriptors
    # print(f"Feature Descriptors: {featuresDescriptors}")
    
    # going through each fruit folder in the source path (train or test)
    for fruit_folder in os.listdir(src_path):
        fruit_folder_path = os.path.join(src_path, fruit_folder)
        
        if os.path.isdir(fruit_folder_path):  # checking if the path actually points to a folder
            print(f"Currently Processing Fruit Images of: {fruit_folder}")
            
            # going through each image file in the current folder
            for img in os.listdir(fruit_folder_path):
                img_path = os.path.join(fruit_folder_path, img)
                
                if img.endswith('.jpg'):  # checking if the file is an jpg image
                    img_as_numpy_arr = convertImgToNumpyArr(img_path)
                    if img_as_numpy_arr is None:  # handling image processing error
                        print(f"Error processing image {img_path}")
                    else:
                        # computing the feature vector (HOG, Colour Histogram, etc.)

                        featureMap = {}

                        if('shape' in featuresDescriptors):
                            hogFeatures, _ = computeHOGFeatures(img_as_numpy_arr)
                            featureMap['shape'] = hogFeatures
                            # print("HOG features shape:", hogFeatures.shape)

                        if('colour' in featuresDescriptors):
                            colourHistFeatures = computeColourHist(img_as_numpy_arr)
                            featureMap['colour'] = colourHistFeatures
                            # print("Colour Histogram features shape:", colourHistFeatures.shape)
                        
                        if('texture' in featuresDescriptors):
                            lbpFeatures = computeLBP_Features(img_as_numpy_arr)
                            featureMap['texture'] = lbpFeatures
                            # print("LBP features shape:", lbpFeatures.shape)

                        # # printing the feature map
                        # print("Feature Map:", featureMap)
                        
                        featureVector = np.concatenate([featureMap[feature.lower()] for feature in featuresDescriptors if feature.lower() in featureMap])

                        featureVector = featureVector.astype(np.float32) # converting to float32 for saving storage space
                        print("Feature vector length:", len(featureVector))

                        # creating the respective save path for each feature vector
                        subfolder_path = os.path.relpath(fruit_folder_path, src_path)
                        save_file_name = f"{os.path.splitext(img)[0]}.npy"  # saving file with .npy extension
                        img_save_path = os.path.join(save_path, subfolder_path, save_file_name)
                        
                        # creating the save folder if it doesn't exist
                        os.makedirs(os.path.dirname(img_save_path), exist_ok=True)
                        np.save(img_save_path, featureVector)

# %% [markdown]
# ## **Image Conversion to Features** ##

# %%
# Paths to the train and test folders
train_path = '../../data/fruits-360/Training'
test_path = '../../data/fruits-360/Test'

# Training Images to Features:
print("Processing Training Images")
saveImgFeaturesAsNumpyArr(train_path, '../features/img_HOG_ColourHist_LBP_Hist_Features/Training')

# Testing Images to Features:
print("Processing Testing Images")
saveImgFeaturesAsNumpyArr(test_path, '../features/img_HOG_ColourHist_LBP_Hist_Features/Testing')
# Out:
# Processing Training Images
# Original Image Folder: ../../data/fruits-360/Training
# Saving Image Features Folder: ../features/img_HOG_ColourHist_LBP_Hist_Features/Training
# Feature Descriptors: ['colour, shape', 'texture']
# Currently Processing Fruit Images of: Blackberrie 1
# Feature Map: {'texture': array([0.0092, 0.0157, 0.0135, 0.0541, 0.0645, 0.1236, 0.0261, 0.0463,
#        0.6152, 0.0318])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0091, 0.0184, 0.0157, 0.0555, 0.0675, 0.1203, 0.0292, 0.0443,
#        0.6061, 0.0339])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0129, 0.0272, 0.0218, 0.0756, 0.106 , 0.1438, 0.0418, 0.0562,
#        0.4676, 0.0471])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0191, 0.0392, 0.0305, 0.1148, 0.2268, 0.1859, 0.0532, 0.0644,
#        0.2001, 0.066 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.017 , 0.0343, 0.0291, 0.0927, 0.12  , 0.1661, 0.0481, 0.0662,
#        0.3638, 0.0627])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0142, 0.0267, 0.0267, 0.093 , 0.113 , 0.1622, 0.0509, 0.0594,
#        0.4027, 0.0512])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0153, 0.0277, 0.0277, 0.0935, 0.1215, 0.1532, 0.0479, 0.063 ,
#        0.3987, 0.0515])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0151, 0.0282, 0.0281, 0.0875, 0.1168, 0.1596, 0.0481, 0.0593,
#        0.4017, 0.0556])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0154, 0.0302, 0.0251, 0.0908, 0.1181, 0.1575, 0.0456, 0.0699,
#        0.3904, 0.057 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0204, 0.0379, 0.0324, 0.1162, 0.2336, 0.1756, 0.0592, 0.0622,
#        0.191 , 0.0715])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.017 , 0.0287, 0.027 , 0.0921, 0.1164, 0.1647, 0.0511, 0.064 ,
#        0.3791, 0.0599])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0112, 0.0228, 0.0202, 0.0696, 0.0896, 0.1325, 0.0368, 0.0495,
#        0.5213, 0.0465])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0153, 0.0272, 0.0257, 0.0882, 0.121 , 0.1746, 0.053 , 0.0663,
#        0.3711, 0.0576])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0154, 0.0259, 0.0282, 0.0906, 0.1155, 0.1679, 0.0466, 0.0655,
#        0.3938, 0.0506])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0165, 0.0291, 0.0264, 0.0876, 0.1203, 0.1655, 0.0495, 0.0671,
#        0.3823, 0.0557])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0176, 0.0286, 0.0299, 0.091 , 0.1207, 0.1587, 0.0495, 0.066 ,
#        0.3834, 0.0546])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0086, 0.0156, 0.0143, 0.0599, 0.066 , 0.119 , 0.0303, 0.0399,
#        0.615 , 0.0314])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0168, 0.0288, 0.0246, 0.0875, 0.1175, 0.1541, 0.048 , 0.0583,
#        0.4097, 0.0547])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0153, 0.0287, 0.0278, 0.0891, 0.1169, 0.1609, 0.0503, 0.0619,
#        0.3911, 0.058 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0091, 0.0165, 0.0152, 0.0596, 0.0691, 0.1238, 0.0283, 0.0445,
#        0.6047, 0.0292])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0098, 0.0156, 0.0152, 0.0552, 0.0653, 0.1187, 0.0265, 0.0459,
#        0.6115, 0.0363])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0144, 0.0268, 0.0239, 0.0941, 0.1138, 0.1574, 0.0459, 0.0651,
#        0.4061, 0.0525])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0169, 0.0324, 0.0268, 0.0884, 0.1227, 0.1723, 0.0523, 0.066 ,
#        0.3637, 0.0585])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0141, 0.0265, 0.0256, 0.0934, 0.1058, 0.1573, 0.0464, 0.0582,
#        0.4293, 0.0434])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.01  , 0.0188, 0.0177, 0.0542, 0.0718, 0.125 , 0.0301, 0.0473,
#        0.5923, 0.0328])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0119, 0.0212, 0.0179, 0.065 , 0.0766, 0.1303, 0.0345, 0.0509,
#        0.55  , 0.0417])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0209, 0.038 , 0.029 , 0.1151, 0.1645, 0.1781, 0.0645, 0.0702,
#        0.2487, 0.071 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0143, 0.0289, 0.0248, 0.0934, 0.1157, 0.1537, 0.0468, 0.0635,
#        0.4009, 0.058 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0131, 0.0277, 0.0267, 0.0962, 0.1146, 0.1592, 0.0443, 0.0621,
#        0.404 , 0.0521])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0173, 0.0303, 0.0267, 0.0915, 0.1252, 0.1595, 0.0569, 0.0654,
#        0.3728, 0.0544])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0148, 0.0258, 0.0246, 0.0937, 0.1069, 0.1679, 0.0459, 0.0691,
#        0.4024, 0.0489])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0145, 0.0296, 0.0239, 0.0792, 0.1403, 0.1608, 0.0411, 0.0546,
#        0.4043, 0.0517])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.0297, 0.028 , 0.0943, 0.1177, 0.156 , 0.0486, 0.0651,
#        0.3863, 0.0586])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0171, 0.033 , 0.0296, 0.1094, 0.1867, 0.1873, 0.05  , 0.0648,
#        0.2579, 0.0642])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0146, 0.0278, 0.0257, 0.0941, 0.1132, 0.1676, 0.0479, 0.0657,
#        0.391 , 0.0524])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0181, 0.0299, 0.0249, 0.0912, 0.1137, 0.153 , 0.0476, 0.0578,
#        0.4064, 0.0574])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0174, 0.0301, 0.0278, 0.0964, 0.1258, 0.1519, 0.0484, 0.0684,
#        0.3758, 0.058 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0149, 0.0306, 0.0228, 0.0889, 0.1133, 0.1623, 0.048 , 0.0606,
#        0.4063, 0.0523])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0166, 0.0321, 0.0281, 0.0928, 0.1243, 0.1551, 0.0484, 0.0676,
#        0.3738, 0.0612])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0088, 0.0163, 0.0144, 0.0563, 0.0676, 0.1204, 0.0277, 0.043 ,
#        0.6148, 0.0307])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0172, 0.0308, 0.0263, 0.091 , 0.1171, 0.1661, 0.0471, 0.064 ,
#        0.3747, 0.0657])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0104, 0.0163, 0.0148, 0.0525, 0.065 , 0.1201, 0.026 , 0.045 ,
#        0.6155, 0.0344])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0148, 0.0318, 0.0262, 0.0899, 0.1135, 0.1667, 0.0495, 0.0604,
#        0.3913, 0.0559])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.0273, 0.0238, 0.0743, 0.1051, 0.1475, 0.0415, 0.0547,
#        0.4585, 0.0516])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0124, 0.0208, 0.0194, 0.0684, 0.0844, 0.1349, 0.0351, 0.0503,
#        0.5291, 0.0452])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0137, 0.0259, 0.0236, 0.0976, 0.1019, 0.1568, 0.0503, 0.062 ,
#        0.4199, 0.0483])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0121, 0.0187, 0.016 , 0.0579, 0.0795, 0.1315, 0.0296, 0.0524,
#        0.562 , 0.0403])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0145, 0.0298, 0.022 , 0.081 , 0.1341, 0.1573, 0.0439, 0.0529,
#        0.4123, 0.0522])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.016 , 0.0325, 0.0277, 0.0896, 0.1201, 0.162 , 0.0485, 0.0692,
#        0.3751, 0.0593])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0104, 0.019 , 0.0172, 0.0585, 0.0759, 0.1258, 0.0319, 0.0491,
#        0.5762, 0.036 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0081, 0.0167, 0.0149, 0.0613, 0.0671, 0.1157, 0.0288, 0.0412,
#        0.6147, 0.0315])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0195, 0.039 , 0.0325, 0.113 , 0.176 , 0.1781, 0.0601, 0.0716,
#        0.2404, 0.0698])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0162, 0.035 , 0.0278, 0.107 , 0.1829, 0.186 , 0.0504, 0.0696,
#        0.2664, 0.0587])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0154, 0.0299, 0.0265, 0.0944, 0.1124, 0.1601, 0.0478, 0.0648,
#        0.3882, 0.0605])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0151, 0.0266, 0.0251, 0.0956, 0.108 , 0.1558, 0.0488, 0.0634,
#        0.4116, 0.05  ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0162, 0.0313, 0.0278, 0.0966, 0.1183, 0.1615, 0.0527, 0.0691,
#        0.3709, 0.0556])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0152, 0.0286, 0.0241, 0.0887, 0.1148, 0.1646, 0.0522, 0.0652,
#        0.393 , 0.0536])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0146, 0.0286, 0.0258, 0.0874, 0.1177, 0.1622, 0.0493, 0.0628,
#        0.398 , 0.0536])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0197, 0.0363, 0.0307, 0.115 , 0.1662, 0.1802, 0.0657, 0.0701,
#        0.2458, 0.0703])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.02  , 0.0412, 0.0339, 0.1132, 0.1673, 0.1737, 0.0653, 0.0704,
#        0.239 , 0.076 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0144, 0.0268, 0.0253, 0.0924, 0.1163, 0.1603, 0.0485, 0.0615,
#        0.4001, 0.0544])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0086, 0.0168, 0.0155, 0.0564, 0.0665, 0.1209, 0.0298, 0.0453,
#        0.6123, 0.0279])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0103, 0.0204, 0.0144, 0.057 , 0.0735, 0.1238, 0.0277, 0.0464,
#        0.5898, 0.0367])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0178, 0.032 , 0.0241, 0.0875, 0.1201, 0.1595, 0.0489, 0.0655,
#        0.3882, 0.0564])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0172, 0.0291, 0.0292, 0.0894, 0.1106, 0.1532, 0.0491, 0.0577,
#        0.4043, 0.0602])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0193, 0.03  , 0.0256, 0.093 , 0.1266, 0.1589, 0.0496, 0.0658,
#        0.3643, 0.0669])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0156, 0.0306, 0.0242, 0.091 , 0.1093, 0.1581, 0.0511, 0.066 ,
#        0.4028, 0.0513])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.026 , 0.0275, 0.0915, 0.1175, 0.1597, 0.0474, 0.0614,
#        0.4   , 0.0533])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0125, 0.0207, 0.018 , 0.0673, 0.0796, 0.1335, 0.0359, 0.0509,
#        0.5397, 0.0419])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0092, 0.0166, 0.0169, 0.0544, 0.0665, 0.1175, 0.0265, 0.0435,
#        0.6163, 0.0326])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0151, 0.0292, 0.0271, 0.0929, 0.1142, 0.1594, 0.0444, 0.0604,
#        0.3989, 0.0584])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0094, 0.0164, 0.0154, 0.056 , 0.0665, 0.1169, 0.0268, 0.0467,
#        0.6108, 0.0351])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0115, 0.0222, 0.017 , 0.0603, 0.0786, 0.1296, 0.0305, 0.0515,
#        0.562 , 0.0368])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0121, 0.027 , 0.0206, 0.0678, 0.103 , 0.1383, 0.0383, 0.0524,
#        0.4938, 0.0467])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.015 , 0.0281, 0.0259, 0.0914, 0.1123, 0.1516, 0.0466, 0.0604,
#        0.4147, 0.054 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.015 , 0.0304, 0.0231, 0.0863, 0.157 , 0.1606, 0.0469, 0.056 ,
#        0.37  , 0.0547])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0169, 0.0306, 0.025 , 0.0987, 0.1212, 0.1615, 0.0445, 0.0674,
#        0.3753, 0.0589])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0145, 0.0232, 0.0247, 0.0824, 0.1294, 0.1541, 0.04  , 0.0543,
#        0.4336, 0.0438])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0159, 0.0296, 0.0283, 0.0921, 0.118 , 0.1613, 0.0501, 0.0621,
#        0.3839, 0.0587])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0209, 0.0349, 0.0342, 0.1127, 0.1697, 0.1797, 0.0608, 0.0686,
#        0.2489, 0.0696])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0183, 0.028 , 0.0238, 0.1007, 0.1339, 0.1741, 0.0492, 0.0662,
#        0.3487, 0.0571])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0107, 0.0178, 0.0157, 0.062 , 0.071 , 0.1285, 0.0301, 0.0457,
#        0.5846, 0.0339])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0183, 0.03  , 0.0278, 0.0935, 0.1232, 0.1673, 0.0492, 0.067 ,
#        0.3653, 0.0584])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0177, 0.0302, 0.0271, 0.0934, 0.1216, 0.1634, 0.0502, 0.0674,
#        0.3708, 0.0582])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0147, 0.027 , 0.0239, 0.0846, 0.1099, 0.1568, 0.0455, 0.0587,
#        0.4339, 0.045 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0133, 0.0246, 0.0213, 0.0767, 0.1029, 0.1472, 0.0373, 0.0577,
#        0.467 , 0.052 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0091, 0.0174, 0.017 , 0.0515, 0.0647, 0.1221, 0.0278, 0.0434,
#        0.6122, 0.0348])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0191, 0.0403, 0.0315, 0.1198, 0.2253, 0.1816, 0.0504, 0.0648,
#        0.2008, 0.0664])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0177, 0.0327, 0.0242, 0.1027, 0.1826, 0.1801, 0.0493, 0.0638,
#        0.2908, 0.0561])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0186, 0.0339, 0.0271, 0.103 , 0.1759, 0.1778, 0.0536, 0.0634,
#        0.2875, 0.0592])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0167, 0.0292, 0.0262, 0.0932, 0.1132, 0.1686, 0.0517, 0.0627,
#        0.3822, 0.0563])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0202, 0.0387, 0.0319, 0.1206, 0.2287, 0.1762, 0.053 , 0.0634,
#        0.1902, 0.0771])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0109, 0.0227, 0.0207, 0.0704, 0.0869, 0.135 , 0.0398, 0.0543,
#        0.5153, 0.044 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0098, 0.0183, 0.0169, 0.0627, 0.0764, 0.1262, 0.0308, 0.0522,
#        0.57  , 0.0367])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0132, 0.0242, 0.0255, 0.0978, 0.1162, 0.1566, 0.0477, 0.0602,
#        0.4048, 0.0538])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0149, 0.0266, 0.0275, 0.0935, 0.1206, 0.1614, 0.0437, 0.064 ,
#        0.3988, 0.049 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0148, 0.0265, 0.0289, 0.0879, 0.1141, 0.1647, 0.0514, 0.063 ,
#        0.3951, 0.0536])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0178, 0.033 , 0.0261, 0.1001, 0.1483, 0.1945, 0.0592, 0.0674,
#        0.2879, 0.0657])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0141, 0.0273, 0.028 , 0.0926, 0.1263, 0.1584, 0.0504, 0.0692,
#        0.3741, 0.0596])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.031 , 0.0244, 0.0908, 0.1236, 0.1603, 0.0489, 0.0633,
#        0.3829, 0.0591])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0161, 0.0265, 0.0251, 0.0866, 0.1157, 0.1639, 0.0482, 0.0647,
#        0.4008, 0.0524])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.016 , 0.0287, 0.0248, 0.0924, 0.1113, 0.157 , 0.0466, 0.0629,
#        0.4042, 0.0561])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.0283, 0.024 , 0.0876, 0.116 , 0.1495, 0.0488, 0.0595,
#        0.4161, 0.0545])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.01  , 0.0174, 0.0141, 0.0581, 0.0682, 0.1168, 0.0275, 0.0378,
#        0.6162, 0.0339])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0089, 0.0136, 0.0158, 0.0549, 0.0654, 0.1134, 0.0254, 0.0413,
#        0.6275, 0.0338])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0114, 0.0214, 0.0178, 0.0632, 0.0798, 0.1324, 0.0333, 0.0516,
#        0.5428, 0.0463])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0093, 0.0156, 0.0166, 0.0545, 0.062 , 0.1203, 0.0253, 0.0479,
#        0.6149, 0.0336])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.015 , 0.0299, 0.0269, 0.0924, 0.1172, 0.1616, 0.0455, 0.0658,
#        0.3883, 0.0574])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0162, 0.031 , 0.0256, 0.0884, 0.1125, 0.1593, 0.0465, 0.0648,
#        0.3941, 0.0616])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0133, 0.0276, 0.0242, 0.0898, 0.1099, 0.1608, 0.0456, 0.062 ,
#        0.4181, 0.0487])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0162, 0.0307, 0.028 , 0.0926, 0.1159, 0.1691, 0.0507, 0.0663,
#        0.3683, 0.0622])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0173, 0.0305, 0.0258, 0.0938, 0.121 , 0.1659, 0.0491, 0.0685,
#        0.3716, 0.0565])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0138, 0.0286, 0.0241, 0.0943, 0.1135, 0.1547, 0.0467, 0.0617,
#        0.4095, 0.0531])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0117, 0.0191, 0.0162, 0.0569, 0.076 , 0.1257, 0.03  , 0.0492,
#        0.5827, 0.0325])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0096, 0.0172, 0.0153, 0.0544, 0.0702, 0.1265, 0.0269, 0.0465,
#        0.599 , 0.0344])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0165, 0.0304, 0.0245, 0.0878, 0.1133, 0.1667, 0.0439, 0.0618,
#        0.4051, 0.05  ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0175, 0.03  , 0.0266, 0.0935, 0.1252, 0.1552, 0.0507, 0.0642,
#        0.3747, 0.0624])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0195, 0.0378, 0.0294, 0.1197, 0.2164, 0.1837, 0.0585, 0.0631,
#        0.2116, 0.0603])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0164, 0.0318, 0.0258, 0.0861, 0.1123, 0.1528, 0.0441, 0.0622,
#        0.4087, 0.0598])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0179, 0.0284, 0.0277, 0.0891, 0.1178, 0.1535, 0.0489, 0.0603,
#        0.3995, 0.0569])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0166, 0.0309, 0.0254, 0.0875, 0.1182, 0.1536, 0.0495, 0.0609,
#        0.3992, 0.0582])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0148, 0.0271, 0.0266, 0.0918, 0.1132, 0.1645, 0.0494, 0.0639,
#        0.3967, 0.052 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0158, 0.0302, 0.0277, 0.0942, 0.1108, 0.1615, 0.0464, 0.0653,
#        0.3896, 0.0585])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.031 , 0.0272, 0.0943, 0.1183, 0.1581, 0.0525, 0.0648,
#        0.3746, 0.0635])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0141, 0.0319, 0.0287, 0.095 , 0.1157, 0.16  , 0.0459, 0.0616,
#        0.3895, 0.0576])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0163, 0.0258, 0.0277, 0.0951, 0.1139, 0.161 , 0.0526, 0.0676,
#        0.3911, 0.0489])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0211, 0.0396, 0.0313, 0.116 , 0.1632, 0.1844, 0.0607, 0.0746,
#        0.2309, 0.0782])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.02  , 0.0398, 0.03  , 0.1174, 0.1642, 0.1796, 0.0654, 0.0746,
#        0.2377, 0.0713])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0088, 0.017 , 0.0138, 0.0551, 0.0671, 0.1115, 0.0282, 0.0426,
#        0.6184, 0.0375])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0146, 0.0297, 0.025 , 0.0971, 0.1249, 0.1729, 0.0466, 0.0654,
#        0.3666, 0.0572])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0186, 0.0366, 0.0302, 0.1129, 0.1622, 0.1793, 0.059 , 0.0683,
#        0.2626, 0.0703])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0155, 0.0296, 0.024 , 0.0887, 0.1139, 0.1591, 0.0479, 0.0639,
#        0.4024, 0.055 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0144, 0.0285, 0.0253, 0.0828, 0.1349, 0.1526, 0.0429, 0.0605,
#        0.4087, 0.0494])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0166, 0.0287, 0.0262, 0.0913, 0.1647, 0.1664, 0.0474, 0.0592,
#        0.3475, 0.052 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0165, 0.0325, 0.0241, 0.0943, 0.1289, 0.1737, 0.0504, 0.0663,
#        0.3481, 0.0652])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0127, 0.0224, 0.0168, 0.0721, 0.0958, 0.1454, 0.0334, 0.0531,
#        0.5032, 0.0451])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.011 , 0.0222, 0.0179, 0.0577, 0.071 , 0.1242, 0.032 , 0.0479,
#        0.5787, 0.0374])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0123, 0.0265, 0.0195, 0.0688, 0.1148, 0.1463, 0.0344, 0.0522,
#        0.4792, 0.046 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0158, 0.0275, 0.0258, 0.0877, 0.1132, 0.148 , 0.0472, 0.0628,
#        0.4179, 0.0541])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0116, 0.0205, 0.0199, 0.0579, 0.0854, 0.1313, 0.0271, 0.0504,
#        0.5553, 0.0406])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0094, 0.0161, 0.0146, 0.0551, 0.0647, 0.1181, 0.0286, 0.0417,
#        0.6171, 0.0346])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0102, 0.0169, 0.0128, 0.0556, 0.0664, 0.1164, 0.0247, 0.0424,
#        0.6233, 0.0313])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0155, 0.027 , 0.0228, 0.0783, 0.1051, 0.1536, 0.0437, 0.0628,
#        0.4352, 0.056 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0097, 0.0187, 0.0175, 0.0609, 0.0718, 0.1252, 0.0273, 0.0458,
#        0.591 , 0.0321])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0104, 0.0198, 0.0188, 0.07  , 0.086 , 0.1303, 0.0353, 0.0528,
#        0.5323, 0.0443])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0158, 0.0298, 0.023 , 0.0853, 0.1099, 0.1677, 0.0463, 0.0648,
#        0.4006, 0.0568])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0188, 0.0367, 0.0312, 0.1179, 0.2202, 0.1866, 0.0597, 0.0599,
#        0.196 , 0.073 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0182, 0.034 , 0.0284, 0.0946, 0.1689, 0.179 , 0.0513, 0.0623,
#        0.3036, 0.0597])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0148, 0.0288, 0.0272, 0.0905, 0.124 , 0.1518, 0.0443, 0.0623,
#        0.3994, 0.0569])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0146, 0.0273, 0.0229, 0.0885, 0.1137, 0.1609, 0.0484, 0.0597,
#        0.4116, 0.0524])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0148, 0.0286, 0.0267, 0.0913, 0.1142, 0.1625, 0.0485, 0.067 ,
#        0.3909, 0.0555])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0169, 0.0332, 0.0289, 0.0977, 0.1174, 0.1595, 0.049 , 0.0679,
#        0.3672, 0.0623])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0182, 0.0323, 0.0281, 0.0918, 0.1269, 0.1638, 0.0482, 0.0689,
#        0.3596, 0.0622])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0094, 0.0199, 0.0159, 0.0508, 0.0714, 0.1232, 0.0278, 0.0446,
#        0.6013, 0.0357])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0195, 0.0267, 0.026 , 0.097 , 0.1692, 0.1798, 0.0502, 0.0595,
#        0.3212, 0.0509])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0187, 0.0399, 0.032 , 0.1116, 0.2239, 0.1807, 0.0583, 0.0628,
#        0.2019, 0.0702])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0161, 0.0314, 0.027 , 0.087 , 0.1187, 0.1598, 0.0475, 0.0651,
#        0.386 , 0.0614])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0096, 0.0169, 0.0154, 0.0551, 0.0657, 0.1161, 0.0283, 0.0424,
#        0.6201, 0.0304])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0142, 0.0251, 0.0228, 0.0799, 0.1012, 0.1449, 0.0421, 0.0563,
#        0.4668, 0.0467])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0136, 0.0264, 0.0233, 0.091 , 0.1142, 0.1598, 0.0445, 0.0627,
#        0.4117, 0.0528])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0102, 0.018 , 0.0163, 0.0542, 0.0672, 0.1211, 0.0286, 0.0467,
#        0.6014, 0.0363])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0166, 0.0329, 0.0245, 0.0935, 0.1222, 0.1677, 0.0473, 0.0645,
#        0.3748, 0.056 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0183, 0.0343, 0.0263, 0.0976, 0.12  , 0.1595, 0.0529, 0.0648,
#        0.3643, 0.062 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0155, 0.0292, 0.0265, 0.0901, 0.114 , 0.163 , 0.0487, 0.0686,
#        0.3846, 0.0598])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0154, 0.0306, 0.0289, 0.095 , 0.1169, 0.1568, 0.0514, 0.0675,
#        0.3791, 0.0584])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0109, 0.0192, 0.0165, 0.0638, 0.0726, 0.1286, 0.0339, 0.0498,
#        0.5657, 0.039 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0129, 0.0242, 0.0221, 0.0718, 0.092 , 0.1403, 0.0384, 0.0532,
#        0.4961, 0.049 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0152, 0.0261, 0.0232, 0.0935, 0.1208, 0.1523, 0.0501, 0.0648,
#        0.4011, 0.0529])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0204, 0.0342, 0.0306, 0.1089, 0.1589, 0.1829, 0.0588, 0.0722,
#        0.2683, 0.0648])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0141, 0.0323, 0.0256, 0.0878, 0.1121, 0.1623, 0.0481, 0.0592,
#        0.4058, 0.0527])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0148, 0.0275, 0.0251, 0.0898, 0.1188, 0.1609, 0.0463, 0.0631,
#        0.4009, 0.0528])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0149, 0.0259, 0.0253, 0.0954, 0.1188, 0.1642, 0.0455, 0.0642,
#        0.3944, 0.0514])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0152, 0.0286, 0.0285, 0.0954, 0.1142, 0.1613, 0.0526, 0.0644,
#        0.3885, 0.0513])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0172, 0.0288, 0.0285, 0.1077, 0.145 , 0.1979, 0.055 , 0.0694,
#        0.2886, 0.0619])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0154, 0.0286, 0.0268, 0.0892, 0.1178, 0.159 , 0.0473, 0.0619,
#        0.4017, 0.0523])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0174, 0.0265, 0.0234, 0.0857, 0.1176, 0.1631, 0.047 , 0.0567,
#        0.4098, 0.0528])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0155, 0.0285, 0.0261, 0.0892, 0.119 , 0.1565, 0.0473, 0.0597,
#        0.4041, 0.0541])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0162, 0.0307, 0.0235, 0.086 , 0.1197, 0.1607, 0.0478, 0.0677,
#        0.3876, 0.0601])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0106, 0.0169, 0.0151, 0.0611, 0.0729, 0.1274, 0.0286, 0.0502,
#        0.5796, 0.0376])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0158, 0.0363, 0.0278, 0.0942, 0.1707, 0.1772, 0.0469, 0.0655,
#        0.3076, 0.058 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0173, 0.0316, 0.0246, 0.0902, 0.1174, 0.1578, 0.0469, 0.0658,
#        0.3898, 0.0586])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0159, 0.03  , 0.0245, 0.0912, 0.1185, 0.1503, 0.0486, 0.0622,
#        0.4013, 0.0575])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0176, 0.0317, 0.0265, 0.1013, 0.1746, 0.1773, 0.0495, 0.0666,
#        0.302 , 0.0529])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0146, 0.0259, 0.0244, 0.0953, 0.1177, 0.1611, 0.0424, 0.0678,
#        0.3955, 0.0553])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.01  , 0.0168, 0.0145, 0.0526, 0.0669, 0.1262, 0.0249, 0.0448,
#        0.6074, 0.0359])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0089, 0.0142, 0.0173, 0.0548, 0.0662, 0.1213, 0.025 , 0.0458,
#        0.6141, 0.0324])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0182, 0.0354, 0.0266, 0.0929, 0.1214, 0.1601, 0.052 , 0.0658,
#        0.3604, 0.0672])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0104, 0.0182, 0.0148, 0.0528, 0.07  , 0.1279, 0.0273, 0.0472,
#        0.5976, 0.0338])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0096, 0.0166, 0.0169, 0.0545, 0.0644, 0.1207, 0.0275, 0.0463,
#        0.613 , 0.0305])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0152, 0.0257, 0.0252, 0.0954, 0.1131, 0.1531, 0.0447, 0.0624,
#        0.4148, 0.0504])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0159, 0.0316, 0.0243, 0.095 , 0.1233, 0.1631, 0.0489, 0.0626,
#        0.3752, 0.0601])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0135, 0.0232, 0.0202, 0.0691, 0.0895, 0.149 , 0.0374, 0.0558,
#        0.4954, 0.0469])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0156, 0.031 , 0.0282, 0.0908, 0.1181, 0.1604, 0.0452, 0.0624,
#        0.389 , 0.0593])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0106, 0.0212, 0.0184, 0.0596, 0.073 , 0.1333, 0.0324, 0.0497,
#        0.5622, 0.0396])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0094, 0.0192, 0.0157, 0.0548, 0.0702, 0.1198, 0.0271, 0.0443,
#        0.6047, 0.0348])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0188, 0.0351, 0.0287, 0.1087, 0.1542, 0.1853, 0.0592, 0.0729,
#        0.2719, 0.0652])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0152, 0.0279, 0.0234, 0.0912, 0.1193, 0.155 , 0.0498, 0.0612,
#        0.4029, 0.0541])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0207, 0.0365, 0.0322, 0.1146, 0.176 , 0.1831, 0.0608, 0.0712,
#        0.234 , 0.0709])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0182, 0.0316, 0.0287, 0.1039, 0.1512, 0.1973, 0.057 , 0.0728,
#        0.2782, 0.0611])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0168, 0.0296, 0.0249, 0.0934, 0.1168, 0.1642, 0.0526, 0.0635,
#        0.3858, 0.0524])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.027 , 0.0237, 0.0904, 0.1216, 0.1629, 0.0479, 0.0628,
#        0.3963, 0.0517])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0165, 0.0308, 0.0285, 0.0903, 0.1251, 0.1546, 0.0479, 0.062 ,
#        0.3892, 0.0551])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.018 , 0.0298, 0.0268, 0.0936, 0.1249, 0.1562, 0.0451, 0.0641,
#        0.381 , 0.0605])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0186, 0.0353, 0.0305, 0.1132, 0.2116, 0.1783, 0.0554, 0.0635,
#        0.2281, 0.0655])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0176, 0.0294, 0.0258, 0.0961, 0.1242, 0.1636, 0.0511, 0.067 ,
#        0.3666, 0.0586])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0162, 0.0264, 0.0257, 0.0931, 0.1129, 0.1624, 0.0456, 0.061 ,
#        0.4009, 0.0558])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0186, 0.0418, 0.0279, 0.1179, 0.2274, 0.1836, 0.0568, 0.0643,
#        0.1952, 0.0665])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0181, 0.0304, 0.0244, 0.0863, 0.1129, 0.1631, 0.0504, 0.0592,
#        0.3927, 0.0625])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0106, 0.0189, 0.0157, 0.0584, 0.0737, 0.1261, 0.0289, 0.0496,
#        0.5807, 0.0374])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0215, 0.0405, 0.03  , 0.1166, 0.1684, 0.1779, 0.0609, 0.0704,
#        0.233 , 0.0808])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0169, 0.0274, 0.025 , 0.0922, 0.1135, 0.1591, 0.0488, 0.064 ,
#        0.3968, 0.0563])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0162, 0.0269, 0.0245, 0.0948, 0.1147, 0.1681, 0.0482, 0.0609,
#        0.3875, 0.0582])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0156, 0.0323, 0.0272, 0.0912, 0.1194, 0.1592, 0.051 , 0.0644,
#        0.3849, 0.0548])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0163, 0.0261, 0.0262, 0.0943, 0.11  , 0.1556, 0.0452, 0.0629,
#        0.4088, 0.0546])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0149, 0.0299, 0.0245, 0.0908, 0.1111, 0.1612, 0.05  , 0.0628,
#        0.406 , 0.0488])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.016 , 0.0315, 0.0265, 0.0883, 0.1088, 0.1505, 0.0491, 0.0594,
#        0.4126, 0.0573])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0154, 0.0258, 0.0265, 0.0998, 0.1351, 0.1681, 0.0482, 0.0682,
#        0.3578, 0.0551])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0106, 0.0142, 0.0158, 0.0582, 0.0666, 0.1153, 0.0266, 0.0426,
#        0.6167, 0.0334])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0102, 0.0183, 0.0161, 0.0596, 0.0718, 0.1186, 0.0293, 0.0448,
#        0.5969, 0.0344])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0174, 0.0329, 0.0267, 0.0952, 0.1378, 0.1741, 0.0504, 0.0706,
#        0.3292, 0.0657])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0167, 0.0306, 0.0258, 0.0918, 0.1618, 0.1697, 0.0478, 0.0586,
#        0.3416, 0.0556])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0132, 0.0256, 0.0222, 0.0653, 0.1091, 0.1453, 0.033 , 0.0552,
#        0.4854, 0.0457])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.015 , 0.0284, 0.0254, 0.0936, 0.1069, 0.1479, 0.0472, 0.0575,
#        0.4211, 0.057 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0123, 0.024 , 0.0191, 0.073 , 0.0874, 0.1371, 0.0358, 0.0554,
#        0.509 , 0.0469])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.016 , 0.0308, 0.0241, 0.0765, 0.1046, 0.1554, 0.0437, 0.0631,
#        0.4263, 0.0595])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0106, 0.0133, 0.0175, 0.0548, 0.0675, 0.119 , 0.0259, 0.044 ,
#        0.6171, 0.0303])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0109, 0.0194, 0.0175, 0.061 , 0.0755, 0.1244, 0.0318, 0.0491,
#        0.5728, 0.0376])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0129, 0.0261, 0.0205, 0.0795, 0.1141, 0.1442, 0.0416, 0.0545,
#        0.4602, 0.0464])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0165, 0.0313, 0.025 , 0.0892, 0.1409, 0.1608, 0.0429, 0.0603,
#        0.3805, 0.0526])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0167, 0.0321, 0.0252, 0.1018, 0.144 , 0.1728, 0.0516, 0.0725,
#        0.3191, 0.0642])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0191, 0.0389, 0.0309, 0.1144, 0.1749, 0.1821, 0.0613, 0.0666,
#        0.2446, 0.0672])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0094, 0.0147, 0.0139, 0.0562, 0.0629, 0.1162, 0.0259, 0.0408,
#        0.6235, 0.0365])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0147, 0.0252, 0.0205, 0.074 , 0.092 , 0.157 , 0.041 , 0.0552,
#        0.4686, 0.0518])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0101, 0.0153, 0.0149, 0.0514, 0.066 , 0.1198, 0.0269, 0.0432,
#        0.6228, 0.0296])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.008 , 0.0149, 0.0158, 0.0571, 0.0625, 0.124 , 0.028 , 0.043 ,
#        0.6141, 0.0326])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0127, 0.0269, 0.0237, 0.0816, 0.1281, 0.1568, 0.0411, 0.0583,
#        0.4227, 0.0481])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0185, 0.0302, 0.0268, 0.0939, 0.1213, 0.159 , 0.0535, 0.062 ,
#        0.3686, 0.0662])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0122, 0.0244, 0.0168, 0.0636, 0.0959, 0.1379, 0.0315, 0.0534,
#        0.5236, 0.0407])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0159, 0.0271, 0.0289, 0.0906, 0.1122, 0.1593, 0.0477, 0.0603,
#        0.4043, 0.0537])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0156, 0.0293, 0.0255, 0.0851, 0.1124, 0.1669, 0.0475, 0.0618,
#        0.4004, 0.0555])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0099, 0.0169, 0.0162, 0.058 , 0.0674, 0.1245, 0.0268, 0.0452,
#        0.6045, 0.0306])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0094, 0.0149, 0.0159, 0.056 , 0.0629, 0.1184, 0.0283, 0.0466,
#        0.6136, 0.034 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0175, 0.0281, 0.0251, 0.096 , 0.1208, 0.1642, 0.0499, 0.0682,
#        0.3713, 0.0589])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.0283, 0.0258, 0.0897, 0.122 , 0.1549, 0.0486, 0.0605,
#        0.4004, 0.0541])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0149, 0.0298, 0.0263, 0.0882, 0.1112, 0.1582, 0.0456, 0.0607,
#        0.4113, 0.0538])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0114, 0.0189, 0.0144, 0.0568, 0.0725, 0.1289, 0.0258, 0.047 ,
#        0.586 , 0.0383])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0076, 0.0169, 0.0151, 0.0533, 0.0644, 0.1245, 0.0265, 0.0431,
#        0.6183, 0.0303])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0204, 0.0382, 0.0354, 0.114 , 0.1762, 0.1846, 0.0625, 0.0699,
#        0.2299, 0.0689])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0173, 0.0359, 0.0328, 0.1132, 0.1665, 0.1851, 0.0596, 0.0701,
#        0.2532, 0.0663])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0166, 0.0324, 0.0274, 0.0924, 0.1169, 0.157 , 0.0516, 0.0647,
#        0.3777, 0.0633])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0168, 0.0317, 0.0281, 0.0914, 0.1181, 0.1527, 0.0495, 0.0664,
#        0.3832, 0.0621])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0165, 0.0312, 0.0292, 0.0922, 0.1134, 0.1599, 0.0456, 0.0647,
#        0.389 , 0.0583])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0172, 0.0306, 0.0269, 0.0863, 0.1196, 0.1614, 0.051 , 0.0645,
#        0.3857, 0.0568])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0154, 0.0288, 0.0245, 0.0979, 0.1154, 0.1651, 0.0472, 0.0615,
#        0.3857, 0.0585])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.011 , 0.0171, 0.018 , 0.064 , 0.078 , 0.1314, 0.0314, 0.0488,
#        0.5628, 0.0375])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0166, 0.0324, 0.0257, 0.0913, 0.1166, 0.1571, 0.0485, 0.0632,
#        0.3932, 0.0554])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0167, 0.0333, 0.0275, 0.0901, 0.1108, 0.1614, 0.0494, 0.0678,
#        0.3822, 0.0608])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0177, 0.0338, 0.0275, 0.0926, 0.1225, 0.1642, 0.0512, 0.0649,
#        0.3595, 0.0661])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.018 , 0.0302, 0.0279, 0.0933, 0.1235, 0.1581, 0.0467, 0.0659,
#        0.3724, 0.064 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0113, 0.0245, 0.0187, 0.0646, 0.0937, 0.1444, 0.0331, 0.0535,
#        0.5105, 0.0457])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0109, 0.0173, 0.0161, 0.058 , 0.071 , 0.1253, 0.032 , 0.0462,
#        0.5881, 0.0351])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.017 , 0.0333, 0.0277, 0.103 , 0.1451, 0.1868, 0.0568, 0.0695,
#        0.3005, 0.0603])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0157, 0.0298, 0.0238, 0.095 , 0.1199, 0.1508, 0.045 , 0.0646,
#        0.3962, 0.0592])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0163, 0.0296, 0.0271, 0.0943, 0.1167, 0.1656, 0.0504, 0.0648,
#        0.3792, 0.056 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0149, 0.0299, 0.0273, 0.0927, 0.1211, 0.156 , 0.0465, 0.065 ,
#        0.3935, 0.0531])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0151, 0.0269, 0.025 , 0.0961, 0.1167, 0.1567, 0.0476, 0.0595,
#        0.4031, 0.0533])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0179, 0.0282, 0.0262, 0.0887, 0.1152, 0.1552, 0.0516, 0.0593,
#        0.4007, 0.057 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0198, 0.0339, 0.0304, 0.1136, 0.1609, 0.1956, 0.0607, 0.0705,
#        0.248 , 0.0666])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0152, 0.0282, 0.0247, 0.0948, 0.1167, 0.1526, 0.0457, 0.0624,
#        0.4064, 0.0533])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0155, 0.0292, 0.027 , 0.0953, 0.1125, 0.153 , 0.0488, 0.0677,
#        0.397 , 0.054 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.016 , 0.0266, 0.0276, 0.0915, 0.1153, 0.1522, 0.052 , 0.0588,
#        0.4045, 0.0555])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0183, 0.0358, 0.0294, 0.1161, 0.1983, 0.1835, 0.0553, 0.0691,
#        0.237 , 0.0572])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0153, 0.0301, 0.0245, 0.0906, 0.1453, 0.1669, 0.0432, 0.0576,
#        0.3794, 0.0471])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.016 , 0.0285, 0.0229, 0.0908, 0.1213, 0.1806, 0.0495, 0.0685,
#        0.365 , 0.0569])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0097, 0.0164, 0.0159, 0.0581, 0.0694, 0.1196, 0.0269, 0.0434,
#        0.6058, 0.0348])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.016 , 0.0285, 0.0261, 0.0931, 0.1164, 0.1615, 0.0516, 0.0654,
#        0.381 , 0.0604])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.011 , 0.0191, 0.019 , 0.0639, 0.0806, 0.1275, 0.0301, 0.0484,
#        0.5655, 0.0349])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0143, 0.0203, 0.0225, 0.0741, 0.097 , 0.1358, 0.0399, 0.0525,
#        0.4955, 0.0481])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0138, 0.0245, 0.0235, 0.0822, 0.1079, 0.1559, 0.0443, 0.0617,
#        0.4413, 0.0449])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0082, 0.0151, 0.0144, 0.0545, 0.0635, 0.1142, 0.0291, 0.0429,
#        0.6234, 0.0347])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0179, 0.0319, 0.0274, 0.0913, 0.124 , 0.1599, 0.0475, 0.0659,
#        0.3752, 0.059 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0179, 0.0356, 0.0262, 0.1041, 0.1917, 0.1783, 0.0511, 0.06  ,
#        0.2727, 0.0624])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0163, 0.0292, 0.0254, 0.0954, 0.1197, 0.1572, 0.0517, 0.0599,
#        0.3865, 0.0587])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.019 , 0.0365, 0.0286, 0.1208, 0.2245, 0.1792, 0.0586, 0.0638,
#        0.2055, 0.0635])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0177, 0.0316, 0.0263, 0.0944, 0.1171, 0.164 , 0.0489, 0.0674,
#        0.376 , 0.0566])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0194, 0.0302, 0.0291, 0.0927, 0.1165, 0.1685, 0.0478, 0.0672,
#        0.3736, 0.055 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0118, 0.0212, 0.0173, 0.0674, 0.084 , 0.1381, 0.0347, 0.0541,
#        0.5303, 0.0411])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0104, 0.0179, 0.0172, 0.0563, 0.0712, 0.1246, 0.0308, 0.0454,
#        0.5918, 0.0344])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0183, 0.0326, 0.0259, 0.0923, 0.1131, 0.1626, 0.0495, 0.0656,
#        0.3795, 0.0606])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0129, 0.0236, 0.0166, 0.064 , 0.0971, 0.1359, 0.0329, 0.0505,
#        0.5189, 0.0476])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0144, 0.0248, 0.0236, 0.0909, 0.1115, 0.157 , 0.0456, 0.063 ,
#        0.4226, 0.0466])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0118, 0.021 , 0.0176, 0.0578, 0.0786, 0.1274, 0.0265, 0.0522,
#        0.5701, 0.037 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0184, 0.0321, 0.0277, 0.0914, 0.1253, 0.1604, 0.0468, 0.0667,
#        0.3637, 0.0675])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0152, 0.0274, 0.0261, 0.0951, 0.1214, 0.162 , 0.0421, 0.0647,
#        0.3884, 0.0576])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0177, 0.0283, 0.0282, 0.093 , 0.1171, 0.1656, 0.0456, 0.0638,
#        0.3834, 0.0573])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0159, 0.0317, 0.0267, 0.0939, 0.1197, 0.1604, 0.0457, 0.0646,
#        0.3843, 0.0571])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.018 , 0.0316, 0.0294, 0.0988, 0.1435, 0.1851, 0.056 , 0.0663,
#        0.3128, 0.0585])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0147, 0.0293, 0.0268, 0.094 , 0.1142, 0.1583, 0.0476, 0.0629,
#        0.3939, 0.0583])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0141, 0.029 , 0.0264, 0.0831, 0.1375, 0.1658, 0.0443, 0.0578,
#        0.3871, 0.0549])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.016 , 0.0284, 0.0243, 0.0941, 0.1142, 0.1668, 0.0504, 0.0631,
#        0.3831, 0.0596])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.009 , 0.0161, 0.0153, 0.0589, 0.0712, 0.1218, 0.0301, 0.0422,
#        0.5995, 0.0359])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0154, 0.0296, 0.0255, 0.0919, 0.1163, 0.1616, 0.0498, 0.0617,
#        0.3886, 0.0596])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0173, 0.0289, 0.0232, 0.0905, 0.1237, 0.1879, 0.0451, 0.0736,
#        0.3557, 0.0541])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0185, 0.0352, 0.0291, 0.1149, 0.1629, 0.1906, 0.0604, 0.0715,
#        0.2535, 0.0634])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0204, 0.0339, 0.0331, 0.1103, 0.1625, 0.1819, 0.0625, 0.0723,
#        0.2494, 0.0737])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.015 , 0.0287, 0.0272, 0.088 , 0.1162, 0.1529, 0.0494, 0.0605,
#        0.4066, 0.0555])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0155, 0.0297, 0.0217, 0.0945, 0.115 , 0.1522, 0.0439, 0.0646,
#        0.4074, 0.0555])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0161, 0.0307, 0.0259, 0.0912, 0.118 , 0.1568, 0.0487, 0.0604,
#        0.3937, 0.0585])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0177, 0.032 , 0.0272, 0.0938, 0.1216, 0.1655, 0.0526, 0.0693,
#        0.3646, 0.0557])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0085, 0.0168, 0.0156, 0.0543, 0.0627, 0.1162, 0.028 , 0.0426,
#        0.6208, 0.0345])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0078, 0.0157, 0.0152, 0.0542, 0.0628, 0.1136, 0.0297, 0.0391,
#        0.6278, 0.0341])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0119, 0.0256, 0.0263, 0.0864, 0.1069, 0.1565, 0.039 , 0.0605,
#        0.4376, 0.0493])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0173, 0.0301, 0.0264, 0.0931, 0.1218, 0.1615, 0.051 , 0.0663,
#        0.3788, 0.0537])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0189, 0.0327, 0.0324, 0.1041, 0.2016, 0.1739, 0.053 , 0.0647,
#        0.2614, 0.0573])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0161, 0.0299, 0.0236, 0.0884, 0.1478, 0.1671, 0.0415, 0.0574,
#        0.3724, 0.0558])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0084, 0.0151, 0.016 , 0.0557, 0.0641, 0.1166, 0.0253, 0.0414,
#        0.6252, 0.0322])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0094, 0.0166, 0.0169, 0.0582, 0.0631, 0.1166, 0.0312, 0.0422,
#        0.6109, 0.0349])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0175, 0.0303, 0.0275, 0.1036, 0.1449, 0.1827, 0.0515, 0.0687,
#        0.3141, 0.0592])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0089, 0.0166, 0.0182, 0.0553, 0.0622, 0.1233, 0.0277, 0.042 ,
#        0.6171, 0.0287])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0124, 0.0217, 0.0167, 0.0661, 0.0833, 0.1313, 0.0351, 0.0487,
#        0.5456, 0.0391])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.014 , 0.024 , 0.0193, 0.073 , 0.0966, 0.1538, 0.0382, 0.0519,
#        0.4834, 0.0458])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.015 , 0.0284, 0.0266, 0.0931, 0.1129, 0.1514, 0.0483, 0.0627,
#        0.4058, 0.0558])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0161, 0.035 , 0.0273, 0.0951, 0.1229, 0.1617, 0.0505, 0.0651,
#        0.3653, 0.061 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0139, 0.0286, 0.0239, 0.0746, 0.1234, 0.1503, 0.0375, 0.0564,
#        0.4457, 0.0457])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0158, 0.0288, 0.0275, 0.0962, 0.1194, 0.1679, 0.0508, 0.064 ,
# ...
# Feature vector length: 10
# Feature Map: {'texture': array([7.000e-04, 4.500e-03, 1.900e-03, 2.120e-02, 6.230e-02, 9.360e-02,
#        4.300e-03, 1.870e-02, 7.797e-01, 1.310e-02])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.00e+00, 1.20e-03, 7.00e-04, 1.24e-02, 4.00e-02, 7.92e-02,
#        2.20e-03, 1.69e-02, 8.43e-01, 4.40e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.600e-03, 6.200e-03, 7.000e-04, 1.260e-02, 2.970e-02, 8.360e-02,
#        1.900e-03, 2.400e-02, 8.289e-01, 1.080e-02])}
# Feature vector length: 10
# Feature Map: {'texture': array([3.00e-04, 1.50e-03, 1.50e-03, 1.53e-02, 4.61e-02, 8.73e-02,
#        3.20e-03, 1.73e-02, 8.20e-01, 7.50e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([3.000e-04, 2.300e-03, 7.000e-04, 1.850e-02, 5.360e-02, 9.800e-02,
#        4.000e-03, 2.280e-02, 7.896e-01, 1.020e-02])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.    , 0.0018, 0.0014, 0.014 , 0.0306, 0.0842, 0.0028, 0.0184,
#        0.8398, 0.007 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([4.000e-04, 4.900e-03, 2.000e-03, 2.210e-02, 6.080e-02, 9.210e-02,
#        4.100e-03, 1.940e-02, 7.842e-01, 1.000e-02])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0009, 0.002 , 0.002 , 0.0123, 0.0252, 0.085 , 0.0026, 0.0172,
#        0.8461, 0.0067])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0015, 0.0043, 0.0019, 0.013 , 0.0247, 0.0825, 0.0028, 0.0247,
#        0.8338, 0.0108])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 1.900e-03, 8.000e-04, 1.590e-02, 4.820e-02, 9.420e-02,
#        1.800e-03, 2.180e-02, 8.078e-01, 7.400e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 1.200e-03, 7.000e-04, 1.370e-02, 3.980e-02, 8.180e-02,
#        1.500e-03, 1.820e-02, 8.375e-01, 5.600e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.    , 0.0011, 0.0009, 0.0125, 0.0413, 0.0765, 0.0017, 0.0157,
#        0.8463, 0.004 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 1.500e-03, 7.000e-04, 1.090e-02, 3.930e-02, 8.420e-02,
#        3.100e-03, 1.770e-02, 8.381e-01, 4.500e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 1.500e-03, 5.000e-04, 1.290e-02, 4.260e-02, 8.050e-02,
#        1.500e-03, 1.540e-02, 8.404e-01, 4.700e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.000e-03, 1.000e-03, 1.280e-02, 4.130e-02, 8.030e-02,
#        1.000e-03, 1.740e-02, 8.411e-01, 4.000e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.900e-03, 1.500e-03, 1.670e-02, 3.640e-02, 8.650e-02,
#        2.300e-03, 2.080e-02, 8.271e-01, 6.700e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.200e-03, 1.200e-03, 1.440e-02, 3.100e-02, 8.590e-02,
#        1.600e-03, 1.860e-02, 8.404e-01, 5.600e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([3.000e-04, 2.800e-03, 1.500e-03, 2.010e-02, 5.400e-02, 8.990e-02,
#        2.900e-03, 1.910e-02, 8.008e-01, 8.600e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.900e-03, 1.300e-03, 1.610e-02, 4.710e-02, 8.990e-02,
#        2.300e-03, 2.000e-02, 8.147e-01, 6.600e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-03, 6.500e-03, 8.000e-04, 1.460e-02, 2.920e-02, 8.510e-02,
#        2.500e-03, 2.580e-02, 8.238e-01, 1.070e-02])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0011, 0.0066, 0.0017, 0.0133, 0.0368, 0.0854, 0.0035, 0.0232,
#        0.8173, 0.0111])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 2.600e-03, 1.000e-03, 1.730e-02, 4.860e-02, 9.110e-02,
#        4.400e-03, 1.810e-02, 8.075e-01, 9.300e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.    , 0.0015, 0.0016, 0.0131, 0.0304, 0.0881, 0.0027, 0.0202,
#        0.8354, 0.007 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0015, 0.0053, 0.0012, 0.0126, 0.0254, 0.0784, 0.0022, 0.0216,
#        0.8397, 0.0121])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.400e-03, 7.000e-04, 1.280e-02, 4.170e-02, 8.180e-02,
#        1.200e-03, 1.820e-02, 8.372e-01, 4.900e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 2.200e-03, 8.000e-04, 1.490e-02, 4.920e-02, 9.010e-02,
#        2.800e-03, 1.820e-02, 8.172e-01, 4.500e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 4.200e-03, 1.200e-03, 2.010e-02, 5.870e-02, 9.380e-02,
#        4.300e-03, 1.830e-02, 7.892e-01, 1.000e-02])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0014, 0.0053, 0.0045, 0.0322, 0.078 , 0.1086, 0.0091, 0.0223,
#        0.7256, 0.013 ])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.400e-03, 4.000e-04, 1.320e-02, 4.320e-02, 8.320e-02,
#        1.000e-03, 1.750e-02, 8.347e-01, 5.300e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.100e-03, 1.000e-03, 1.200e-02, 4.100e-02, 7.900e-02,
#        1.200e-03, 1.590e-02, 8.423e-01, 6.400e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 1.600e-03, 7.000e-04, 1.090e-02, 4.250e-02, 7.960e-02,
#        1.300e-03, 1.580e-02, 8.421e-01, 5.300e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.    , 0.0018, 0.0014, 0.0141, 0.0362, 0.088 , 0.0024, 0.0187,
#        0.8295, 0.0079])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.    , 0.0019, 0.0014, 0.0157, 0.0357, 0.0882, 0.0021, 0.0204,
#        0.826 , 0.0086])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.000e-03, 4.000e-04, 1.190e-02, 3.830e-02, 7.780e-02,
#        1.300e-03, 1.530e-02, 8.512e-01, 2.700e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.00e-04, 1.10e-03, 4.00e-04, 1.20e-02, 3.95e-02, 7.71e-02,
#        2.40e-03, 1.35e-02, 8.50e-01, 3.80e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 1.700e-03, 8.000e-04, 1.590e-02, 4.410e-02, 8.560e-02,
#        1.900e-03, 2.160e-02, 8.223e-01, 6.100e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.300e-03, 7.000e-04, 1.160e-02, 4.210e-02, 8.370e-02,
#        2.300e-03, 1.520e-02, 8.383e-01, 4.700e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([4.000e-04, 1.400e-03, 7.000e-04, 1.310e-02, 3.870e-02, 7.960e-02,
#        1.500e-03, 1.660e-02, 8.428e-01, 5.200e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.200e-03, 5.000e-04, 1.330e-02, 4.090e-02, 8.520e-02,
#        1.700e-03, 1.750e-02, 8.335e-01, 6.100e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0014, 0.0049, 0.0013, 0.0133, 0.026 , 0.0746, 0.0027, 0.0222,
#        0.8413, 0.0123])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0012, 0.0062, 0.0025, 0.0174, 0.0422, 0.0863, 0.0051, 0.0214,
#        0.8046, 0.0131])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 2.100e-03, 1.000e-03, 1.320e-02, 4.270e-02, 8.410e-02,
#        1.700e-03, 1.790e-02, 8.281e-01, 9.100e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 1.500e-03, 5.000e-04, 1.280e-02, 3.930e-02, 8.210e-02,
#        1.700e-03, 1.690e-02, 8.408e-01, 4.400e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.400e-03, 4.000e-04, 1.180e-02, 3.810e-02, 8.600e-02,
#        2.300e-03, 1.740e-02, 8.362e-01, 6.300e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 2.200e-03, 1.100e-03, 2.000e-02, 5.160e-02, 8.850e-02,
#        3.300e-03, 1.840e-02, 8.076e-01, 7.100e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.    , 0.0017, 0.0012, 0.0145, 0.0308, 0.0844, 0.0016, 0.0203,
#        0.8381, 0.0074])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 1.200e-03, 1.700e-03, 1.480e-02, 3.510e-02, 8.370e-02,
#        2.100e-03, 1.810e-02, 8.379e-01, 5.200e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.00e-04, 1.80e-03, 1.30e-03, 1.46e-02, 3.96e-02, 9.08e-02,
#        2.40e-03, 2.09e-02, 8.22e-01, 6.50e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 2.000e-03, 1.600e-03, 1.680e-02, 4.590e-02, 8.740e-02,
#        3.200e-03, 1.880e-02, 8.191e-01, 5.000e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([5.000e-04, 2.900e-03, 1.700e-03, 1.890e-02, 5.350e-02, 8.870e-02,
#        3.500e-03, 1.850e-02, 8.016e-01, 1.020e-02])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 1.300e-03, 2.200e-03, 1.270e-02, 2.980e-02, 8.050e-02,
#        2.300e-03, 1.500e-02, 8.498e-01, 6.200e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 2.000e-03, 6.000e-04, 1.230e-02, 3.970e-02, 8.100e-02,
#        3.100e-03, 1.720e-02, 8.386e-01, 5.400e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.600e-03, 9.000e-04, 1.130e-02, 4.240e-02, 8.160e-02,
#        8.000e-04, 1.890e-02, 8.346e-01, 7.800e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.400e-03, 4.000e-04, 1.510e-02, 4.370e-02, 8.320e-02,
#        2.100e-03, 1.990e-02, 8.292e-01, 4.900e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.800e-03, 1.100e-03, 1.210e-02, 4.980e-02, 8.930e-02,
#        2.700e-03, 1.830e-02, 8.172e-01, 7.600e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.00e+00, 1.40e-03, 8.00e-04, 1.18e-02, 3.95e-02, 7.89e-02,
#        1.50e-03, 1.39e-02, 8.48e-01, 4.20e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([5.000e-04, 2.600e-03, 1.400e-03, 1.370e-02, 2.680e-02, 7.910e-02,
#        2.700e-03, 1.740e-02, 8.493e-01, 6.500e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0015, 0.0049, 0.0022, 0.0139, 0.0322, 0.0853, 0.0037, 0.0244,
#        0.8215, 0.0104])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.500e-03, 6.000e-04, 1.130e-02, 4.160e-02, 8.670e-02,
#        1.400e-03, 1.660e-02, 8.344e-01, 5.800e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 1.200e-03, 7.000e-04, 1.350e-02, 3.990e-02, 7.860e-02,
#        1.200e-03, 1.590e-02, 8.442e-01, 4.800e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.600e-03, 6.000e-04, 1.270e-02, 4.430e-02, 8.800e-02,
#        2.200e-03, 1.730e-02, 8.278e-01, 5.400e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([3.000e-04, 2.100e-03, 1.000e-03, 1.720e-02, 4.730e-02, 9.200e-02,
#        3.300e-03, 1.900e-02, 8.106e-01, 7.200e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 2.000e-03, 5.000e-04, 1.340e-02, 3.790e-02, 8.420e-02,
#        2.300e-03, 1.750e-02, 8.362e-01, 6.000e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 1.300e-03, 5.000e-04, 1.170e-02, 3.970e-02, 7.940e-02,
#        2.200e-03, 1.650e-02, 8.424e-01, 6.300e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0011, 0.0045, 0.003 , 0.0217, 0.0604, 0.0956, 0.005 , 0.0205,
#        0.7773, 0.0109])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0008, 0.0056, 0.0022, 0.0269, 0.0633, 0.1021, 0.0054, 0.0237,
#        0.7574, 0.0126])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 2.100e-03, 1.200e-03, 1.740e-02, 5.030e-02, 9.040e-02,
#        3.800e-03, 2.020e-02, 8.071e-01, 7.300e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 2.100e-03, 5.000e-04, 1.200e-02, 4.270e-02, 8.310e-02,
#        1.500e-03, 1.780e-02, 8.312e-01, 8.900e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.00e+00, 1.00e-03, 5.00e-04, 1.20e-02, 3.92e-02, 8.08e-02,
#        2.00e-03, 1.61e-02, 8.44e-01, 4.40e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0014, 0.0052, 0.0014, 0.0127, 0.0331, 0.0817, 0.0028, 0.021 ,
#        0.8303, 0.0104])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0012, 0.0056, 0.0014, 0.0128, 0.0246, 0.0824, 0.003 , 0.0241,
#        0.8356, 0.0093])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.000e+00, 1.300e-03, 6.000e-04, 1.280e-02, 4.000e-02, 8.190e-02,
#        1.600e-03, 1.600e-02, 8.404e-01, 5.400e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 2.200e-03, 6.000e-04, 1.410e-02, 4.750e-02, 9.010e-02,
#        3.000e-03, 2.120e-02, 8.126e-01, 8.500e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.300e-03, 8.000e-04, 1.260e-02, 3.940e-02, 8.320e-02,
#        1.900e-03, 1.790e-02, 8.351e-01, 7.700e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.200e-03, 6.000e-04, 1.010e-02, 3.930e-02, 8.170e-02,
#        2.200e-03, 1.480e-02, 8.441e-01, 5.900e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([3.000e-04, 2.500e-03, 1.000e-03, 1.790e-02, 4.810e-02, 8.940e-02,
#        2.300e-03, 1.900e-02, 8.086e-01, 1.090e-02])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.00e+00, 9.00e-04, 5.00e-04, 1.46e-02, 4.38e-02, 8.76e-02,
#        1.60e-03, 2.05e-02, 8.24e-01, 6.50e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 1.600e-03, 1.200e-03, 1.430e-02, 3.600e-02, 8.880e-02,
#        2.600e-03, 1.800e-02, 8.324e-01, 4.900e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0008, 0.004 , 0.0014, 0.0203, 0.061 , 0.0945, 0.0041, 0.0187,
#        0.7841, 0.0111])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0008, 0.0045, 0.0032, 0.0225, 0.0635, 0.0916, 0.0051, 0.0164,
#        0.7822, 0.0102])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 2.200e-03, 1.900e-03, 1.770e-02, 5.290e-02, 9.180e-02,
#        3.900e-03, 1.840e-02, 8.029e-01, 8.100e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 1.200e-03, 5.000e-04, 1.410e-02, 4.480e-02, 8.560e-02,
#        2.700e-03, 1.740e-02, 8.288e-01, 4.800e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([1.000e-04, 9.000e-04, 9.000e-04, 1.260e-02, 4.190e-02, 7.960e-02,
#        1.900e-03, 1.700e-02, 8.385e-01, 6.600e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([2.000e-04, 2.100e-03, 6.000e-04, 1.600e-02, 5.240e-02, 8.890e-02,
#        3.400e-03, 1.870e-02, 8.122e-01, 5.500e-03])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.0014, 0.0073, 0.0025, 0.018 , 0.0426, 0.0886, 0.0052, 0.0249,
#        0.7962, 0.0133])}
# Feature vector length: 10
# Feature Map: {'texture': array([0.    , 0.0026, 0.0013, 0.0124, 0.04  , 0.0829, 0.0023, 0.0171,
#        0.836 , 0.0054])}
# Feature vector length: 10
# Feature Map:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 7
#       5 # Training Images to Features:
#       6 print("Processing Training Images")
# ----> 7 saveImgFeaturesAsNumpyArr(train_path, '../features/img_HOG_ColourHist_LBP_Hist_Features/Training')
#       9 # Testing Images to Features:
#      10 print("Processing Testing Images")
#
# Cell In[20], line 46, in saveImgFeaturesAsNumpyArr(src_path, save_path, featuresDescriptors)
#      42     featureMap['texture'] = lbpFeatures
#      43     # print("LBP features shape:", lbpFeatures.shape)
#      44
#      45 # printing the feature map
# ---> 46 print("Feature Map:", featureMap)
#      48 featureVector = np.concatenate([featureMap[feature.lower()] for feature in featuresDescriptors if feature.lower() in featureMap])
#      50 featureVector = featureVector.astype(np.float32) # converting to float32 for saving storage space
#
# File /opt/anaconda3/envs/PRML/lib/python3.11/site-packages/ipykernel/iostream.py:684, in OutStream.write(self, string)
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
# --> 684     self._buffers[frozenset(parent.items())].write(string)
#     685 if is_child:
#     686     # mp.Pool cannot be trusted to flush promptly (or ever),
#     687     # and this helps.
#     688     if self._subprocess_flush_pending:
#
# KeyboardInterrupt:
